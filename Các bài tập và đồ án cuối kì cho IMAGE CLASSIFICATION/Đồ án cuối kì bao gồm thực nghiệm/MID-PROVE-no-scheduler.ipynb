# %% [markdown]
# # Đây là NOTEBOOK thực nghiệm KHÔNG sử dụng Scheduler "Reduce Lr On Plateau" trong quá trình train, giúp cân nhắc việc sử dụng module này
#
# Các quá trình thực nghiệm được thể hiện trong các notebook sau:
# 1.   [Model MobileNetV3, không scheduler, nhận learning rate = 5e-5](https://colab.research.google.com/drive/119gHyxtZN8JAfFSC8ZN5s_Fn0WGiwjqR?usp=sharing)
# 2.   [Model MobileNetV3, có scheduler "Reduce Lr On Plateau", learning rate = 5e-5](https://colab.research.google.com/drive/1DzKmkps8jJ2h4he-N4VXYBaF10su5Q1j?usp=drive_link)
# 3.   [Model MobileNetV3, không scheduler, learning rate = 1e-8](https://colab.research.google.com/drive/1jIOqals9RLu_IX0TTu7T0_2Gh4Q0_j6-?usp=drive_link)
#
# * Mã nguồn trong 3 NOTEBOOK gần như giống nhau
# * Sự khác biệt của các NOTEBOOK chỉ nằm trong 2 yếu tố Scheduler & Learning rate như trình bày trên
#
# Đường dẫn đến NOTEBOOK giải nghĩa và so sánh:
# <br>
#  https://drive.google.com/file/d/1F1VaHuGNwdoEFH77yuHi-rHKkNMW-88W/view?usp=drive_link

# %% [markdown]
# ## Import các thư viện cần thiết

# %%
import os
import random
from datetime import datetime
from PIL import Image
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from tqdm import tqdm
import pandas as pd

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import transforms, models
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support, accuracy_score
import json
import matplotlib.pyplot as plt
from torch.nn import Dropout

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Biến toàn cục

# %%
label_mapping = {
    'Others': 0,
    'Honda': 1,
    'Suzuki': 2,
    'Yamaha': 3,
    'VinFast': 4
}
reverse_label_mapping={
    0: 'Others',
    1: 'Honda',
    2: 'Suzuki',
    3: 'Yamaha',
    4: 'VinFast'
}

# %% [markdown]
# ## Lớp CustomImageDataset kế thừa từ Dataset để có thể load ảnh theo định dạng của Dataframe chứa đường dẫn các ảnh có thể load được format RGB

# %%
class CustomImageDataset(Dataset):
    def __init__(self, df, save_dir, transform=None):
        self.df = df
        self.save_dir = save_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        # print(self.df.iloc[idx]['full_path'])
        img_path = os.path.join(self.save_dir , self.df.iloc[idx]['full_path'])
        label = self.df.iloc[idx]['label_idx']

        # Open the image file
        image = Image.open(img_path).convert('RGB')

        # Apply transformation if provided
        if self.transform:
            image = self.transform(image)

        return image, label

# %% [markdown]
# ## Lọc ra những đường dẫn của Image có thể load được
# ## Lọc dataframe split 1 của Thầy Duy, thành 1 Dataframe nhỏ hơn (chứa các đường dẫn)
# ## Dataframe nhỏ hơn này có chứa 8000 ảnh có thể load được và được chia thành training set và validation set lần lượt theo tỉ lệ 8:2

# %%
def can_load_image(file_path):
    try:
        image = Image.open(file_path).convert('RGB')
        return True
    except Exception as ex:  # Catch all exceptions (FileNotFoundError, IOError, etc.)
        # print(ex)
        return False

# %%
df_path_split_1 = pd.read_csv("MotocycleDataset-train-clean-1.csv")
df_path_split_1
# Out:
#                                                full_path  label_idx
# 0      ./CLASS-IMAGES/Honda/22520968-22520996-2252099...          1
# 1      ./CLASS-IMAGES/Honda/22520968-22520996-2252099...          1
# 2      ./CLASS-IMAGES/Honda/22520968-22520996-2252099...          1
# 3      ./CLASS-IMAGES/Honda/22520968-22520996-2252099...          1
# 4      ./CLASS-IMAGES/Honda/22520968-22520996-2252099...          1
# ...                                                  ...        ...
# 27774  ./CLASS-IMAGES/Others/22520033-22520035-225200...          0
# 27775  ./CLASS-IMAGES/Others/22520033-22520035-225200...          0
# 27776  ./CLASS-IMAGES/Others/22520033-22520035-225200...          0
# 27777  ./CLASS-IMAGES/Others/22520033-22520035-225200...          0
# 27778  ./CLASS-IMAGES/Others/22520033-22520035-225200...          0
#
# [27779 rows x 2 columns]

# %%
df_path_DEMO = df_path_split_1.sample(8000,ignore_index=True)
df_path_DEMO["full_path"] = df_path_DEMO["full_path"].apply(
    lambda x: x.replace("./CLASS-IMAGES", "./drive/MyDrive/my_shared_shortcut/Public")
)
df_path_DEMO
# Out:
#                                               full_path  label_idx
# 0     ./drive/MyDrive/my_shared_shortcut/Public/Yama...          3
# 1     ./drive/MyDrive/my_shared_shortcut/Public/Yama...          3
# 2     ./drive/MyDrive/my_shared_shortcut/Public/Hond...          1
# 3     ./drive/MyDrive/my_shared_shortcut/Public/Hond...          1
# 4     ./drive/MyDrive/my_shared_shortcut/Public/VinF...          4
# ...                                                 ...        ...
# 7995  ./drive/MyDrive/my_shared_shortcut/Public/Othe...          0
# 7996  ./drive/MyDrive/my_shared_shortcut/Public/Yama...          3
# 7997  ./drive/MyDrive/my_shared_shortcut/Public/Yama...          3
# 7998  ./drive/MyDrive/my_shared_shortcut/Public/VinF...          4
# 7999  ./drive/MyDrive/my_shared_shortcut/Public/Othe...          0
#
# [8000 rows x 2 columns]

# %%
df_path_DEMO.to_csv("DEMO-LEARNING-RATE-UPDATE.csv", index=False)

# %%
train_df, val_df = train_test_split(df_path_DEMO, test_size=0.2, random_state=42)

# %%
train_df.reset_index(drop=True,inplace=True)
train_df.to_csv("DEMO-LEARNING-RATE-train.csv", index=False)
train_df.head()
# Out:
#                                            full_path  label_idx
# 0  ./drive/MyDrive/my_shared_shortcut/Public/Suzu...          2
# 1  ./drive/MyDrive/my_shared_shortcut/Public/VinF...          4
# 2  ./drive/MyDrive/my_shared_shortcut/Public/Othe...          0
# 3  ./drive/MyDrive/my_shared_shortcut/Public/Yama...          3
# 4  ./drive/MyDrive/my_shared_shortcut/Public/Othe...          0

# %%
val_df.reset_index(drop=True,inplace=True)
val_df.to_csv("DEMO-LEARNING-RATE-val.csv", index=False)
val_df.head()
# Out:
#                                            full_path  label_idx
# 0  ./drive/MyDrive/my_shared_shortcut/Public/Othe...          0
# 1  ./drive/MyDrive/my_shared_shortcut/Public/Suzu...          2
# 2  ./drive/MyDrive/my_shared_shortcut/Public/Hond...          1
# 3  ./drive/MyDrive/my_shared_shortcut/Public/Hond...          1
# 4  ./drive/MyDrive/my_shared_shortcut/Public/Suzu...          2

# %% [markdown]
# ## Unzip các resource đã chuẩn bị từ trước (bao gồm các ảnh trong dataset của lớp)
# ## Đọc training set, validation set đã chuẩn bị sẵn từ trước đó

# %%
# !unzip "./drive/MyDrive/my_shared_shortcut/CLASS-IMAGES.zip" -d ./
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.19.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.2.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.20.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.21.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.22.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.23.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.24.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.25.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.26.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.27.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.28.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.29.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.3.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.30.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.31.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.32.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.33.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.34.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.35.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.36.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.37.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.38.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.39.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.4.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.40.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.41.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.42.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.43.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.44.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.45.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.46.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.47.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.48.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.49.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.5.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.50.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.51.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.52.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.53.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.54.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.55.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.56.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.57.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.58.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.59.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.6.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.60.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.61.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.62.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.63.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.64.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.65.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.66.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.67.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.68.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.69.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.7.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.70.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.71.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.72.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.73.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.74.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.75.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.8.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/21522734-21522821.Yamaha.9.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.1.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.10.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.11.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.12.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.13.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.14.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.15.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.16.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.17.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.18.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.19.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.2.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.20.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.21.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.22.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.23.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.24.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.25.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.26.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.27.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.28.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.29.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.3.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.30.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.31.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.32.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.33.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.34.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.35.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.36.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.37.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.38.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.39.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.4.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.40.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.41.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.42.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.43.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.44.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.45.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.46.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.47.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.48.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.49.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.5.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.50.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.51.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.52.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.53.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.54.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.55.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.56.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.57.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.58.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.59.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.6.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.60.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.61.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.62.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.63.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.64.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.65.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.66.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.67.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.68.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.69.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.7.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.70.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.71.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.72.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.73.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.74.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.75.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.76.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.77.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.8.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520003-22520010-22520398-22520630-22520053.yamaha.9.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.1.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.10.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.100.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.101.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.102.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.103.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.104.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.105.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.106.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.107.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.108.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.109.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.11.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.110.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.111.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.112.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.113.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.114.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.115.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.116.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.117.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.118.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.119.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.12.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.120.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.121.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.122.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.123.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.124.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.125.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.13.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.14.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.15.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.16.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.17.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.18.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.19.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.2.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.20.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.21.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.22.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.23.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.24.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.25.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.26.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.27.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.28.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.29.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.3.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.30.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.31.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.32.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.33.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.34.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.35.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.36.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.37.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.38.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.39.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.4.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.40.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.41.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.42.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.43.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.44.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.45.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.46.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.47.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.48.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.49.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.5.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.50.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.51.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.52.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.53.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.54.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.55.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.56.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.57.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.58.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.59.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.6.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.60.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.61.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.62.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.63.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.64.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.65.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.66.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.67.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.68.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.69.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.7.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.70.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.71.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.72.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.73.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.74.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.75.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.76.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.77.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.78.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.79.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.8.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.80.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.81.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.82.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.83.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.84.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.85.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.86.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.87.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.88.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.89.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.9.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.90.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.91.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.92.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.93.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.94.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.95.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.96.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.97.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.98.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520033-22520035-22520083-22520148-22520375.Yamaha.99.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.1.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.10.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.11.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.12.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.13.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.14.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.15.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.16.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.17.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.18.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.19.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.2.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.20.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.21.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.22.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.23.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.24.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.25.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.26.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.27.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.28.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.29.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.3.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.30.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.31.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.32.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.33.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.34.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.35.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.36.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.37.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.38.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.39.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.4.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.40.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.41.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.42.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.43.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.44.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.45.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.46.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.47.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.48.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.49.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.5.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.50.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.51.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.52.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.53.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.6.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.7.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.8.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520054-22521626-22521322.Yamaha.9.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.1.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.10.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.100.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.101.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.102.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.103.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.104.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.105.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.106.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.107.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.108.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.109.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.11.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.110.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.111.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.112.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.113.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.114.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.115.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.116.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.117.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.118.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.119.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.12.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.120.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.121.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.122.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.123.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.124.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.125.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.13.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.14.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.15.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.16.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.17.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.18.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.19.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.2.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.20.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.21.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.22.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.23.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.24.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.25.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.26.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.27.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.28.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.29.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.3.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.30.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.31.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.32.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.33.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.34.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.35.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.36.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.37.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.38.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.39.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.4.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.40.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.41.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.42.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.43.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.44.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.45.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.46.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.47.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.48.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.49.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.5.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.50.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.51.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.52.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.53.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.54.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.55.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.56.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.57.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.58.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.59.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.6.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.60.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.61.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.62.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.63.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.64.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.65.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.66.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.67.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.68.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.69.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.7.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.70.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.71.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.72.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.73.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.74.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.75.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.76.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.77.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.78.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.79.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.8.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.80.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.81.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.82.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.83.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.84.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.85.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.86.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.87.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.88.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.89.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.9.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.90.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.91.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.92.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.93.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.94.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.95.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.96.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.97.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.98.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520193-22520234-22520363.Yamaha.99.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520197.Yamaha.1.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520197.Yamaha.10.png
#   inflating: ./CLASS-IMAGES/Yamaha/22520197.Yamaha.2.png
#   inflating: ./CLASS-IMAGES/Yamaha/22520197.Yamaha.3.png
#   inflating: ./CLASS-IMAGES/Yamaha/22520197.Yamaha.4.png
#   inflating: ./CLASS-IMAGES/Yamaha/22520197.Yamaha.5.png
#   inflating: ./CLASS-IMAGES/Yamaha/22520197.Yamaha.6.png
#   inflating: ./CLASS-IMAGES/Yamaha/22520197.Yamaha.7.png
#   inflating: ./CLASS-IMAGES/Yamaha/22520197.Yamaha.8.png
#   inflating: ./CLASS-IMAGES/Yamaha/22520197.Yamaha.9.png
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.1.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.10.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.11.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.12.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.13.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.14.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.15.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.16.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.17.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.18.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.19.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.2.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.20.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.21.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.22.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.23.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.24.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.25.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.26.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.27.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.28.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.29.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.3.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.30.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.31.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.32.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.33.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.34.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.35.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.36.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.37.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.38.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.39.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.4.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.5.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.6.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.7.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.8.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520327.Yamaha.9.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.1.png
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.10.png
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.100.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.101.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.102.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.103.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.104.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.105.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.106.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.107.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.108.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.109.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.11.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.110.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.111.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.112.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.113.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.114.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.115.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.116.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.117.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.118.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.119.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.12.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.120.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.121.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.122.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.123.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.124.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.125.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.126.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.127.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.128.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.129.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.13.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.130.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.131.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.132.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.133.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.134.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.135.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.136.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.137.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.138.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.139.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.14.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.140.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.141.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.142.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.143.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.144.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.145.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.146.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.147.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.148.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.149.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.15.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.150.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.151.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.152.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.153.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.154.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.155.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.156.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.157.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.158.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.159.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.16.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.160.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.161.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.162.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.163.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.164.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22520356-22520424-22520460-22520467-22521129.Yamaha.165.jpg
# ...
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.341.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.342.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.343.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.344.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.345.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.346.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.347.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.348.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.349.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.35.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.350.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.351.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.352.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.353.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.354.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.355.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.356.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.357.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.358.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.359.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.36.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.360.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.361.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.362.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.363.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.364.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.365.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.366.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.367.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.368.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.369.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.37.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.370.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.371.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.372.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.373.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.374.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.375.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.376.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.377.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.378.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.379.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.38.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.380.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.381.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.382.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.383.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.384.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.385.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.386.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.387.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.388.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.389.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.39.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.390.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.391.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.392.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.393.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.394.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.395.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.396.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.397.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.398.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.399.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.4.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.40.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.400.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.401.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.402.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.403.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.404.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.405.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.406.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.407.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.408.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.409.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.41.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.410.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.411.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.412.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.413.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.414.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.415.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.416.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.417.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.418.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.419.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.42.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.420.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.421.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.422.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.423.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.424.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.425.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.426.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.427.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.428.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.429.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.43.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.430.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.431.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.432.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.433.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.434.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.44.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.45.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.46.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.47.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.48.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.49.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.5.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.50.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.51.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.52.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.53.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.54.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.55.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.56.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.57.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.58.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.59.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.6.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.60.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.61.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.62.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.63.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.64.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.65.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.66.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.67.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.68.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.69.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.7.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.70.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.71.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.72.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.73.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.74.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.75.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.76.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.77.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.78.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.79.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.8.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.80.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.81.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.82.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.83.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.84.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.85.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.86.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.87.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.88.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.89.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.9.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.90.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.91.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.92.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.93.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.94.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.95.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.96.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.97.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.98.jpg
#   inflating: ./CLASS-IMAGES/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.99.jpg

# %% [markdown]
# ## Đọc lại Dataframe từ csv: danh sách đường dẫn các ảnh dùng để train và validate

# %%
train_df = pd.read_csv("./drive/MyDrive/my_shared_shortcut/MODELS-logs/DEMO-LEARNING-RATE-train.csv")
val_df = pd.read_csv("./drive/MyDrive/my_shared_shortcut/MODELS-logs/DEMO-LEARNING-RATE-val.csv")

# %% [markdown]
# ## Visualize một vài ảnh từ Dataloader (torch.utils.data.DataLoader)

# %%
transform = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.ToTensor()
    ])
dataset = CustomImageDataset(train_df, save_dir="./", transform=transform)

# %%
def show_images(images, labels, n_images=10, mapping={}):
    images = images.permute(0, 2, 3, 1).numpy()
    fig, axes = plt.subplots(1, n_images, figsize=(15, 15))
    for i in range(n_images):
        image = images[i]
        label = mapping[labels[i].item()]
        # Show the image
        ax = axes[i]
        ax.imshow(image)
        ax.axis('off')
        ax.set_title(label)

    plt.show()

# %%
data_loader_display = DataLoader(dataset, batch_size=32, shuffle=True)
data_iter_transformed = iter(data_loader_display)
images, labels = next(data_iter_transformed)

# %%
show_images(images[:10], labels, n_images=10,mapping=reverse_label_mapping)
show_images(images[10:20], labels, n_images=10,mapping=reverse_label_mapping)
show_images(images[20:], labels, n_images=10, mapping=reverse_label_mapping)
# show_images(images[30:32], labels, n_images=10, mapping=reverse_label_mapping)

# %% [markdown]
# ## Chuẩn bị quá trình train

# %% [markdown]
# ### Chuẩn bị các hàm cần thiết để train Model
# ### Ở đây NOTEBOOK này sử dụng Scheduler để update Learning rate dựa trên min validation loss
#
# Giải nghĩa hàm **"save_model"**: lưu lại các thước đo trong quá trình train làm **"check point"**. Các thước đo sẽ được sử dụng sau này để visualize và so sánh trong [NOTEBOOK so sánh](https://drive.google.com/file/d/1F1VaHuGNwdoEFH77yuHi-rHKkNMW-88W/view?usp=drive_link):
# * learning rate: để theo dõi xem learning rate có bị update over epoch không
# * epoch: thông tin lần train hiện tại là bao nhiêu
# * train loss: giá trị của hàm Cross Entropy Loss tính được trong quá trình train
# * validation loss: giá trị của hàm Cross Entropy Loss tính được trong quá trình validate
# * checkpoint_savedir: địa điểm lưu lại các thước đo
# <br>
#
# Giải nghĩa hàm **"train_model"**: hàm chạy quá trình train theo framework của [PyTorch](https://pytorch.org/tutorials/beginner/blitz/neural_networks_tutorial.html):
# * model: model được chọn trong quá trình train
# * train_loader: [DataLoader](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html) của training set
# * val_loader: [DataLoader](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html) của validation set
# * criterion: module để tính loss [Cross Entropy loss](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html)
# * optimizer: module dùng để tối ưu trong quá trình chạy.
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Vd: zero_grad() dùng để reset gradient sau khi thực hiện propagation và backpropagation sau mỗi batch
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Vd: optimizer.step() cập nhật weights sau khi đã thực hiện backpropagation
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;.....
# <br>
# * early_stopping: dừng sớm khi validation loss không cải thiện sau nhiều epochs
#
# Chú ý: Scheduler không được sử dụng trong hàm train này

# %%
def save_model(learning_rate, epoch, train_loss, val_loss, train_acc, val_acc, checkpoint_savedir):
    save_dict = {
        "lr": learning_rate,
        "val_loss": val_loss,
        "train_loss": train_loss,
        "train_acc": train_acc,
        "val_acc": val_acc
    }
    checkpoint_path = os.path.join(checkpoint_savedir, f'epoch_{epoch}.pth')
    torch.save(save_dict, checkpoint_path)
    print(f"saved model at epoch {epoch}: {checkpoint_path}")

def train_model(model, train_loader: DataLoader, val_loader: DataLoader,
                criterion, optimizer, current_epoch, num_epochs, checkpoint_savedir='./models', early_stopping=None):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"device: {device}")
    model.to(device)

    best_loss = float('inf')
    train_size = len(train_loader.dataset)
    val_size = len(val_loader.dataset)
    print(f"train size: {train_size}")
    print(f"val size: {val_size}")

    for epoch in range(current_epoch, num_epochs + 1):
        model.train()
        running_loss = 0.0

        # Training Phase
        train_corrects = 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)

            _, preds = torch.max(outputs, 1)

            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            train_corrects += torch.sum(preds == labels.data)

        epoch_loss = running_loss / train_size
        train_acc = train_corrects * 100 / train_size
        print(f"Training Loss: {epoch_loss:.6f} ; Acc: {train_acc:.4f}")

        # Validation Phase
        model.eval()
        val_loss = 0.0
        val_corrects = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * inputs.size(0)
                val_corrects += torch.sum(preds == labels.data)

        val_epoch_loss = val_loss / val_size
        val_acc = val_corrects * 100 / val_size
        print(f"Validation Loss: {val_epoch_loss:.4f}; Acc: {val_acc:.4f}")

        # Log Learning Rate
        current_lr = optimizer.param_groups[0]['lr']
        print(f"Learning Rate: {current_lr:.6f}")

        # Save checkpoint
        os.makedirs(checkpoint_savedir, exist_ok=True)
        save_model(current_lr, epoch, epoch_loss, val_epoch_loss, train_acc, val_acc, checkpoint_savedir)

        if early_stopping:
            early_stopping.consume_loss(val_loss, model)
            if early_stopping.early_stop:
                print("Early stopping!!!!!!!!!!!!!!!!!!")
                break

        # Save the best model based on validation loss
        if val_epoch_loss < best_loss:
            best_loss = val_epoch_loss
            best_model_path = os.path.join(checkpoint_savedir, 'best_model.pth')
            torch.save(model.state_dict(), best_model_path)
            print(f"Best model updated with validation loss {best_loss:.4f} and saved at {best_model_path}")

# %% [markdown]
# ### Các transform để tăng cường hóa training Dataset trong quá trình train

# %%
IMG_SIZE = 360
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(IMG_SIZE),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.RandomPerspective(distortion_scale=0.2, p=0.5),
    transforms.RandomGrayscale(p=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

val_transform = transforms.Compose([
    transforms.Resize(IMG_SIZE),
    transforms.CenterCrop(IMG_SIZE-24),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %% [markdown]
# ### Định nghĩa model, cùng với các hyper-parameter có thể dùng để tinh chỉnh quá trình train
# * In ra model của MobileNetV3, sau đó copy layer cuối cùng và chỉnh sửa out_features = 5 (đại diện cho 5 label)
# * Device: chọn device để train
# * criterion: module tính loss (ở đây sử dụng Cross Entropy Loss)
# * optimizer: module giúp thực hiện quá trình train, cụ thể là thực hiện propagation và backpropagation, cũng như cập nhật weights, reset gradient sau mỗi batch, set learning rate ban đầu (5e-5)
# <br>
#
# Chú ý: NOTEBOOK này không sử dụng scheduler, learning rate được để ngang bằng với việc train cùng scheduler 5e-5

# %%
num_classes = 5  # Number of classes in your dataset
model = models.mobilenet_v3_large(weights='DEFAULT')

model.classifier = nn.Sequential(
    nn.Linear(in_features=960, out_features=1280, bias=True),
    nn.Hardswish(),
    nn.Dropout(p=0.2),
    nn.Linear(in_features=1280, out_features=5, bias=True)
)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
model.to(device)

# Define criterion, optimizer,
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=5e-5)
# Out:
# cuda

# %% [markdown]
# ### Chuẩn bị Training dataset và Validation dataset, cũng như Dataloader lần lượt tương ứng Traing loader và validation loader

# %%
train_dataset = CustomImageDataset(train_df,save_dir='./',transform=train_transform)
val_dataset=CustomImageDataset(val_df,save_dir='./',transform=val_transform)
# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# ## Bắt đầu quá trình train:
# num_epochs: số epoch muốn train.
# Ở đây epoch là số lần mà quá trình train đi qua toàn bộ dataset (one complete pass of the training dataset through the algorithm)
# Trong quá trình train đã log ra các thước đo như:
# Khuôn mẫu log của một epoch có format như sau:
#
# ---
#
# Training Loss: 0.346330 ; Acc: 86.8906
# <br>
# Validation Loss: 0.9022; Acc: 78.0000
# <br>
# Learning Rate: 0.000050
# <br>
# saved metrics at epoch 36: ./drive/MyDrive/Models/PROVE-LEARNING-RATE-MODELS/epoch_36.pth
# <br>
# saved model at epoch 36: ./models-MobileNetV3-no-scheduler/epoch_36.pth
#
# ---
#
# * current training epoch: 36
# * Training loss:  0.346330
# * Training accuracy: 86.8906%
# * validation loss: 0.9022
# * validation accuracy: 78.0000%
# * Learning rate: 0.000050
# * Vị trí lưu các thước đo:  ./drive/MyDrive/Models/PROVE-LEARNING-RATE-MODELS/epoch_36.pth
# * Vị trí lưu model tốt nhất (loss thấp nhất): ./drive/MyDrive/Models/PROVE-LEARNING-RATE-MODELS/best_model.pth

# %%
num_epochs=70
current_epoch = 1
import warnings
warnings.filterwarnings("ignore", module="PIL")
early_stopping = EarlyStopping(patience=20, verbose=True)
train_model(model, train_loader, val_loader, criterion, optimizer,
            current_epoch, num_epochs, checkpoint_savedir='./models-MobileNetV3-no-scheduler',early_stopping=None)
# Out:
# device: cuda
# train size: 6400
# val size: 1600
# Training Loss: 1.328463 ; Acc: 43.0781
# Validation Loss: 1.1684; Acc: 50.0625
# Learning Rate: 0.000050
# saved model at epoch 1: ./models-MobileNetV3-no-scheduler/epoch_1.pth
# Best model updated with validation loss 1.1684 and saved at ./models-MobileNetV3-no-scheduler/best_model.pth
# Training Loss: 1.171390 ; Acc: 51.6406
# Validation Loss: 1.1119; Acc: 53.8750
# Learning Rate: 0.000050
# saved model at epoch 2: ./models-MobileNetV3-no-scheduler/epoch_2.pth
# Best model updated with validation loss 1.1119 and saved at ./models-MobileNetV3-no-scheduler/best_model.pth
# Training Loss: 1.062917 ; Acc: 56.4531
# Validation Loss: 0.9375; Acc: 62.1250
# Learning Rate: 0.000050
# saved model at epoch 3: ./models-MobileNetV3-no-scheduler/epoch_3.pth
# Best model updated with validation loss 0.9375 and saved at ./models-MobileNetV3-no-scheduler/best_model.pth
# Training Loss: 0.981102 ; Acc: 61.1875
# Validation Loss: 0.8994; Acc: 63.5000
# Learning Rate: 0.000050
# saved model at epoch 4: ./models-MobileNetV3-no-scheduler/epoch_4.pth
# Best model updated with validation loss 0.8994 and saved at ./models-MobileNetV3-no-scheduler/best_model.pth
# Training Loss: 0.912887 ; Acc: 63.9062
# Validation Loss: 0.8958; Acc: 65.5625
# Learning Rate: 0.000050
# saved model at epoch 5: ./models-MobileNetV3-no-scheduler/epoch_5.pth
# Best model updated with validation loss 0.8958 and saved at ./models-MobileNetV3-no-scheduler/best_model.pth
# Training Loss: 0.873897 ; Acc: 64.9375
# Validation Loss: 0.9777; Acc: 62.8750
# Learning Rate: 0.000050
# saved model at epoch 6: ./models-MobileNetV3-no-scheduler/epoch_6.pth
# Training Loss: 0.828272 ; Acc: 67.7500
# Validation Loss: 0.8359; Acc: 67.6250
# Learning Rate: 0.000050
# saved model at epoch 7: ./models-MobileNetV3-no-scheduler/epoch_7.pth
# Best model updated with validation loss 0.8359 and saved at ./models-MobileNetV3-no-scheduler/best_model.pth
# Training Loss: 0.794447 ; Acc: 68.7656
# Validation Loss: 0.7777; Acc: 70.0000
# Learning Rate: 0.000050
# saved model at epoch 8: ./models-MobileNetV3-no-scheduler/epoch_8.pth
# Best model updated with validation loss 0.7777 and saved at ./models-MobileNetV3-no-scheduler/best_model.pth
# Training Loss: 0.760347 ; Acc: 70.5938
# Validation Loss: 0.7958; Acc: 69.8125
# Learning Rate: 0.000050
# saved model at epoch 9: ./models-MobileNetV3-no-scheduler/epoch_9.pth
# Training Loss: 0.725480 ; Acc: 72.2344
# Validation Loss: 0.8330; Acc: 69.4375
# Learning Rate: 0.000050
# saved model at epoch 10: ./models-MobileNetV3-no-scheduler/epoch_10.pth
# Training Loss: 0.677217 ; Acc: 73.8906
# Validation Loss: 0.8113; Acc: 70.8125
# Learning Rate: 0.000050
# saved model at epoch 11: ./models-MobileNetV3-no-scheduler/epoch_11.pth
# Training Loss: 0.650790 ; Acc: 75.3594
# Validation Loss: 0.7921; Acc: 71.5625
# Learning Rate: 0.000050
# saved model at epoch 12: ./models-MobileNetV3-no-scheduler/epoch_12.pth
# Training Loss: 0.662017 ; Acc: 74.7188
# Validation Loss: 0.7916; Acc: 72.3125
# Learning Rate: 0.000050
# saved model at epoch 13: ./models-MobileNetV3-no-scheduler/epoch_13.pth
# Training Loss: 0.600801 ; Acc: 76.9219
# Validation Loss: 0.7642; Acc: 72.9375
# Learning Rate: 0.000050
# saved model at epoch 14: ./models-MobileNetV3-no-scheduler/epoch_14.pth
# Best model updated with validation loss 0.7642 and saved at ./models-MobileNetV3-no-scheduler/best_model.pth
# Training Loss: 0.591204 ; Acc: 77.8281
# Validation Loss: 0.8023; Acc: 72.4375
# Learning Rate: 0.000050
# saved model at epoch 15: ./models-MobileNetV3-no-scheduler/epoch_15.pth
# Training Loss: 0.576374 ; Acc: 78.0156
# Validation Loss: 0.7780; Acc: 74.5625
# Learning Rate: 0.000050
# saved model at epoch 16: ./models-MobileNetV3-no-scheduler/epoch_16.pth
# Training Loss: 0.553534 ; Acc: 78.9844
# Validation Loss: 0.8033; Acc: 73.8125
# Learning Rate: 0.000050
# saved model at epoch 17: ./models-MobileNetV3-no-scheduler/epoch_17.pth
# Training Loss: 0.533195 ; Acc: 79.8594
# Validation Loss: 0.8414; Acc: 73.1250
# Learning Rate: 0.000050
# saved model at epoch 18: ./models-MobileNetV3-no-scheduler/epoch_18.pth
# Training Loss: 0.525462 ; Acc: 80.2500
# Validation Loss: 0.8104; Acc: 75.8750
# Learning Rate: 0.000050
# saved model at epoch 19: ./models-MobileNetV3-no-scheduler/epoch_19.pth
# Training Loss: 0.499298 ; Acc: 80.7812
# Validation Loss: 0.7747; Acc: 74.7500
# Learning Rate: 0.000050
# saved model at epoch 20: ./models-MobileNetV3-no-scheduler/epoch_20.pth
# Training Loss: 0.495698 ; Acc: 81.0312
# Validation Loss: 0.7982; Acc: 74.6250
# Learning Rate: 0.000050
# saved model at epoch 21: ./models-MobileNetV3-no-scheduler/epoch_21.pth
# Training Loss: 0.497707 ; Acc: 81.7031
# Validation Loss: 0.7833; Acc: 75.6250
# Learning Rate: 0.000050
# saved model at epoch 22: ./models-MobileNetV3-no-scheduler/epoch_22.pth
# Training Loss: 0.466153 ; Acc: 82.5156
# Validation Loss: 0.8295; Acc: 74.3750
# Learning Rate: 0.000050
# saved model at epoch 23: ./models-MobileNetV3-no-scheduler/epoch_23.pth
# Training Loss: 0.453493 ; Acc: 83.2344
# Validation Loss: 0.8004; Acc: 74.6875
# Learning Rate: 0.000050
# saved model at epoch 24: ./models-MobileNetV3-no-scheduler/epoch_24.pth
# Training Loss: 0.457791 ; Acc: 82.8438
# Validation Loss: 0.8221; Acc: 74.7500
# Learning Rate: 0.000050
# saved model at epoch 25: ./models-MobileNetV3-no-scheduler/epoch_25.pth
# Training Loss: 0.429970 ; Acc: 83.9688
# Validation Loss: 0.8517; Acc: 75.1875
# Learning Rate: 0.000050
# saved model at epoch 26: ./models-MobileNetV3-no-scheduler/epoch_26.pth
# Training Loss: 0.433603 ; Acc: 83.7500
# Validation Loss: 0.8074; Acc: 75.8125
# Learning Rate: 0.000050
# saved model at epoch 27: ./models-MobileNetV3-no-scheduler/epoch_27.pth
# Training Loss: 0.399722 ; Acc: 85.1719
# Validation Loss: 0.8184; Acc: 76.4375
# Learning Rate: 0.000050
# saved model at epoch 28: ./models-MobileNetV3-no-scheduler/epoch_28.pth
# Training Loss: 0.408290 ; Acc: 84.9688
# Validation Loss: 0.8768; Acc: 75.3125
# Learning Rate: 0.000050
# saved model at epoch 29: ./models-MobileNetV3-no-scheduler/epoch_29.pth
# Training Loss: 0.398489 ; Acc: 84.9062
# Validation Loss: 0.8576; Acc: 76.3750
# Learning Rate: 0.000050
# saved model at epoch 30: ./models-MobileNetV3-no-scheduler/epoch_30.pth
# Training Loss: 0.388329 ; Acc: 85.6406
# Validation Loss: 0.8362; Acc: 76.1875
# Learning Rate: 0.000050
# saved model at epoch 31: ./models-MobileNetV3-no-scheduler/epoch_31.pth
# Training Loss: 0.395740 ; Acc: 85.3125
# Validation Loss: 0.8571; Acc: 77.2500
# Learning Rate: 0.000050
# saved model at epoch 32: ./models-MobileNetV3-no-scheduler/epoch_32.pth
# Training Loss: 0.378256 ; Acc: 85.6250
# Validation Loss: 0.8521; Acc: 76.3750
# Learning Rate: 0.000050
# saved model at epoch 33: ./models-MobileNetV3-no-scheduler/epoch_33.pth
# Training Loss: 0.358119 ; Acc: 86.8125
# Validation Loss: 0.9102; Acc: 76.2500
# Learning Rate: 0.000050
# saved model at epoch 34: ./models-MobileNetV3-no-scheduler/epoch_34.pth
# Training Loss: 0.364820 ; Acc: 86.5781
# Validation Loss: 0.9284; Acc: 76.5625
# Learning Rate: 0.000050
# saved model at epoch 35: ./models-MobileNetV3-no-scheduler/epoch_35.pth
# Training Loss: 0.346330 ; Acc: 86.8906
# Validation Loss: 0.9022; Acc: 78.0000
# Learning Rate: 0.000050
# saved model at epoch 36: ./models-MobileNetV3-no-scheduler/epoch_36.pth
# Training Loss: 0.351582 ; Acc: 87.1250
# Validation Loss: 0.9792; Acc: 75.9375
# Learning Rate: 0.000050
# saved model at epoch 37: ./models-MobileNetV3-no-scheduler/epoch_37.pth
# Training Loss: 0.351058 ; Acc: 86.9531
# Validation Loss: 0.9730; Acc: 76.8750
# Learning Rate: 0.000050
# saved model at epoch 38: ./models-MobileNetV3-no-scheduler/epoch_38.pth
# Training Loss: 0.338548 ; Acc: 87.7031
# Validation Loss: 0.8698; Acc: 77.5625
# Learning Rate: 0.000050
# saved model at epoch 39: ./models-MobileNetV3-no-scheduler/epoch_39.pth
# Training Loss: 0.328912 ; Acc: 87.3281
# Validation Loss: 0.8832; Acc: 77.7500
# Learning Rate: 0.000050
# saved model at epoch 40: ./models-MobileNetV3-no-scheduler/epoch_40.pth
